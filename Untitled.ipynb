# %%
import pandas as pd

# %%
datos = pd.read_csv('profesores_detalle.csv', sep="|")
# Out:
# /home/joelerll/espol-2017/inteligencia_artifical/G9-IA2017/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cols = list(datos)

# %%
cols.insert(0, cols.pop(cols.index('codigo_materia')))

# %%
datos = datos.loc[:, cols]

# %%
datos = datos.drop('link', 1) # numero_preguntas

# %%
datos = datos[datos['numero_preguntas'] == 26]

# %%
pd.set_option('display.max_columns', 500)
datos.head(3)
# Out:
#   codigo_materia                     profesor unidad  \
# 1      ICHE05074  MARÍA DEL CARMEN,PERÉ JALIL   FCSH
# 2      ICHE05074  MARÍA DEL CARMEN,PERÉ JALIL   FCSH
# 3      ICHE05074  MARÍA DEL CARMEN,PERÉ JALIL   FCSH
#
#                                              materia paralelo  anio periodo  \
# 1  ACERCAMIENTO A LA LITERATURA LATINOAMERICANA C...       31  2016      1S
# 2  ACERCAMIENTO A LA LITERATURA LATINOAMERICANA C...       31  2016      2S
# 3  ACERCAMIENTO A LA LITERATURA LATINOAMERICANA C...       31  2015      2S
#
#    estudiantes_registrados  estudiantes_evaluados  \
# 1                       18                     14
# 2                       31                     17
# 3                       33                     24
#
#    numero_estudiantes_fuera_periodo  numero_preguntas  promedio_unidad  \
# 1                                 1                26            86.52
# 2                                 1                26            88.67
# ...

# %%
datos.to_csv('features.csv')
